# %%
import pandas as pd
import statsmodels.api as sm
from linearmodels import PooledOLS
from linearmodels.panel import PanelOLS

# %% [markdown]
# ### Issuers

# %%
df = pd.read_csv('source/fractions.csv', index_col=['IssuerId', 'TrdExctnDt'], parse_dates=['TrdExctnDt'])

pooled_x = sm.add_constant(df[['LagWeekInstitutionalFraction', 'LagWeekRetailFraction', 'LagWeekUnFraction']])
pooled_y = df['InstitutionalFraction']
pooled_olsr_model = PanelOLS(dependent=pooled_y, exog=pooled_x, entity_effects=True)
pooled_olsr_model.fit(cov_type='clustered', cluster_entity=True)
# Out:
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     InstitutionalFraction   R-squared:                        0.0003
# Estimator:                      PanelOLS   R-squared (Between):          -7.408e-05
# No. Observations:                 324234   R-squared (Within):               0.0003
# Date:                   Mon, Sep 18 2023   R-squared (Overall):              0.0008
# Time:                           17:04:59   Log-likelihood                -3.986e+05
# Cov. Estimator:                Clustered
#                                            F-statistic:                      37.191
# Entities:                           1367   P-value                           0.0000
# Avg Obs:                          237.19   Distribution:                F(3,322864)
# Min Obs:                          1.0000
# Max Obs:                          2853.0   F-statistic (robust):             29.686
#                                            P-value                           0.0000
# Time periods:                       2879   Distribution:                F(3,322864)
# Avg Obs:                          112.62
# Min Obs:                          1.0000
# Max Obs:                          363.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# const                            0.0123  9.936e-05     123.51     0.0000      0.0121      0.0125
# LagWeekInstitutionalFraction     0.0129     0.0020     6.5054     0.0000      0.0090      0.0168
# LagWeekRetailFraction            0.0116     0.0024     4.9037     0.0000      0.0070      0.0163
# LagWeekUnFraction                0.0070     0.0020     3.5473     0.0004      0.0031      0.0109
# ================================================================================================
#
# F-test for Poolability: 3.0743
# P-value: 0.0000
# Distribution: F(1366,322864)
#
# Included effects: Entity
# PanelEffectsResults, id: 0x7f918a8ebbb0

# %%
df = pd.read_csv('source/fractions.csv', index_col=['IssuerId', 'TrdExctnDt'], parse_dates=['TrdExctnDt'])

pooled_x = sm.add_constant(df[['LagMonthInstitutionalFraction', 'LagMonthRetailFraction', 'LagMonthUnFraction']])
pooled_y = df['InstitutionalFraction']
pooled_olsr_model = PanelOLS(dependent=pooled_y, exog=pooled_x, entity_effects=True)
pooled_olsr_model.fit(cov_type='clustered', cluster_entity=True)
# Out:
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     InstitutionalFraction   R-squared:                     2.994e-05
# Estimator:                      PanelOLS   R-squared (Between):             -0.0027
# No. Observations:                 324234   R-squared (Within):            2.994e-05
# Date:                   Mon, Sep 18 2023   R-squared (Overall):           7.988e-05
# Time:                           17:05:25   Log-likelihood                -3.986e+05
# Cov. Estimator:                Clustered
#                                            F-statistic:                      3.2227
# Entities:                           1367   P-value                           0.0216
# Avg Obs:                          237.19   Distribution:                F(3,322864)
# Min Obs:                          1.0000
# Max Obs:                          2853.0   F-statistic (robust):             2.3821
#                                            P-value                           0.0674
# Time periods:                       2879   Distribution:                F(3,322864)
# Avg Obs:                          112.62
# Min Obs:                          1.0000
# Max Obs:                          363.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# const                             0.0129     0.0001     109.21     0.0000      0.0127      0.0132
# LagMonthInstitutionalFraction     0.0011     0.0021     0.5412     0.5884     -0.0029      0.0051
# LagMonthRetailFraction           -0.0021     0.0024    -0.8919     0.3725     -0.0067      0.0025
# LagMonthUnFraction                0.0051     0.0021     2.4653     0.0137      0.0010      0.0092
# =================================================================================================
#
# F-test for Poolability: 3.1621
# P-value: 0.0000
# Distribution: F(1366,322864)
#
# Included effects: Entity
# PanelEffectsResults, id: 0x7f917aca7b50

# %% [markdown]
# ### Issuers

# %%
df = pd.read_csv('source/fractions_issuers.csv', index_col=['IssuerId', 'TrdExctnDt'], parse_dates=['TrdExctnDt'])

pooled_x = sm.add_constant(df[['LagWeekInstitunionalFraction', 'LagWeekRetailFraction']])
pooled_y = df['InstitunionalFraction']
pooled_olsr_model = PanelOLS(dependent=pooled_y, exog=pooled_x, entity_effects=True)
pooled_olsr_model.fit(cov_type='clustered', cluster_entity=True)
# Out:
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     InstitunionalFraction   R-squared:                        0.0003
# Estimator:                      PanelOLS   R-squared (Between):             -0.0104
# No. Observations:                 743114   R-squared (Within):               0.0003
# Date:                   Wed, Sep 13 2023   R-squared (Overall):              0.0005
# Time:                           12:46:26   Log-likelihood                -9.694e+05
# Cov. Estimator:                Clustered
#                                            F-statistic:                      102.49
# Entities:                           2029   P-value                           0.0000
# Avg Obs:                          366.25   Distribution:                F(2,741083)
# Min Obs:                          1.0000
# Max Obs:                          2871.0   F-statistic (robust):             76.328
#                                            P-value                           0.0000
# Time periods:                       2897   Distribution:                F(2,741083)
# Avg Obs:                          256.51
# Min Obs:                          1.0000
# Max Obs:                          557.00
#
#                                       Parameter Estimates
# ================================================================================================
#                               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------------------------
# const                            0.0200  4.041e-05     494.03     0.0000      0.0199      0.0200
# LagWeekInstitunionalFraction     0.0122     0.0013     9.2379     0.0000      0.0096      0.0148
# LagWeekRetailFraction            0.0121     0.0015     8.2855     0.0000      0.0092      0.0149
# ================================================================================================
#
# F-test for Poolability: 2.9849
# P-value: 0.0000
# Distribution: F(2028,741083)
#
# Included effects: Entity
# PanelEffectsResults, id: 0x7fce7b08fdf0

# %%
pooled_x = sm.add_constant(df[['LagMonthInstitunionalFraction', 'LagMonthRetailFraction']])
pooled_y = df['InstitunionalFraction']
pooled_olsr_model = PanelOLS(dependent=pooled_y, exog=pooled_x, entity_effects=True)
pooled_olsr_model.fit(cov_type='clustered', cluster_entity=True)
# Out:
#                             PanelOLS Estimation Summary
# ===================================================================================
# Dep. Variable:     InstitunionalFraction   R-squared:                     3.694e-05
# Estimator:                      PanelOLS   R-squared (Between):             -0.0099
# No. Observations:                 743114   R-squared (Within):            3.694e-05
# Date:                   Wed, Sep 13 2023   R-squared (Overall):              0.0001
# Time:                           12:46:27   Log-likelihood                -9.695e+05
# Cov. Estimator:                Clustered
#                                            F-statistic:                      13.689
# Entities:                           2029   P-value                           0.0000
# Avg Obs:                          366.25   Distribution:                F(2,741083)
# Min Obs:                          1.0000
# Max Obs:                          2871.0   F-statistic (robust):             11.658
#                                            P-value                           0.0000
# Time periods:                       2897   Distribution:                F(2,741083)
# Avg Obs:                          256.51
# Min Obs:                          1.0000
# Max Obs:                          557.00
#
#                                        Parameter Estimates
# =================================================================================================
#                                Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------------------------
# const                             0.0203  4.586e-05     442.26     0.0000      0.0202      0.0204
# LagMonthInstitunionalFraction     0.0056     0.0013     4.3070     0.0000      0.0031      0.0081
# LagMonthRetailFraction            0.0026     0.0015     1.7665     0.0773     -0.0003      0.0055
# =================================================================================================
#
# F-test for Poolability: 3.0541
# P-value: 0.0000
# Distribution: F(2028,741083)
#
# Included effects: Entity
# PanelEffectsResults, id: 0x7fce7b08d450
