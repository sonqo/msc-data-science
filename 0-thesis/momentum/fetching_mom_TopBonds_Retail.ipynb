# %%
import os
import pandas as pd
import sqlalchemy as db
from dotenv import load_dotenv

# %%
load_dotenv()

# config and credentials
server = os.getenv('DB_SERVER')
database = os.getenv('DB_NAME')
username = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')

# connection
engine = db.create_engine(
    'mssql://{}:{}@{}/{}?driver=ODBC+Driver+18+for+SQL+Server'.format(
        username, password, server, database
    )
)

# establish connection
connection = engine.connect()

# %% [markdown]
# ### Top Bonds

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        NULL, -- CreditRisk : IG | HY
        NULL -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail.csv', index=False)

# %% [markdown]
# ### Investment Grade

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        'IG', -- CreditRisk : IG | HY
        NULL -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail-IG.csv', index=False)

# %% [markdown]
# ### High Yield

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        'HY', -- CreditRisk : IG | HY
        NULL -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail-HY.csv', index=False)

# %% [markdown]
# ### Private

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        NULL, -- CreditRisk : IG | HY
        'Private' -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail-Private.csv', index=False)

# %% [markdown]
# ### Public

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        NULL, -- CreditRisk : IG | HY
        'Public' -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail-Public.csv', index=False)

# %% [markdown]
# ### Investment Grade & Private

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        'IG', -- CreditRisk : IG | HY
        'Private' -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail-Private-IG.csv', index=False)

# %% [markdown]
# ### Investment Grade & Public

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        'IG', -- CreditRisk : IG | HY
        'Public' -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail-Public-IG.csv', index=False)

# %% [markdown]
# ### High Yield & Private

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        'HY', -- CreditRisk : IG | HY
        'Private' -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail-Private-HY.csv', index=False)

# %% [markdown]
# ### High Yield & Public

# %%
query = '''
    DECLARE @RC int
    EXECUTE @RC = [dbo].[sp_mom_TopBonds_Retail]
        'HY', -- CreditRisk : IG | HY
        'Public' -- Ownership : Private | Public
'''

# read sql
df = pd.read_sql_query(query, connection)
df.to_csv('data/mom-TopBondsRetail-Public-HY.csv', index=False)
